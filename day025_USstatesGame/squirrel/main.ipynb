# %%
import pandas as pd

df = pd.read_csv("2018_Central_Park_Squirrel_Census_-_Squirrel_Data_20250622.csv")
df.head()
# Out:
#            X          Y Unique Squirrel ID Hectare Shift      Date  \
# 0 -73.956134  40.794082     37F-PM-1014-03     37F    PM  10142018
# 1 -73.968857  40.783783     21B-AM-1019-04     21B    AM  10192018
# 2 -73.974281  40.775534     11B-PM-1014-08     11B    PM  10142018
# 3 -73.959641  40.790313     32E-PM-1017-14     32E    PM  10172018
# 4 -73.970268  40.776213     13E-AM-1017-05     13E    AM  10172018
#
#    Hectare Squirrel Number    Age Primary Fur Color Highlight Fur Color  ...  \
# 0                        3    NaN               NaN                 NaN  ...
# 1                        4    NaN               NaN                 NaN  ...
# 2                        8    NaN              Gray                 NaN  ...
# 3                       14  Adult              Gray                 NaN  ...
# 4                        5  Adult              Gray            Cinnamon  ...
#
#   Approaches Indifferent Runs from Other Interactions  \
# ...

# %%
fur_col = df["Primary Fur Color"].value_counts()
fur_col.to_csv("squirrel_fur_color_cont.csv")

# %%
df_fur_col = pd.read_csv("squirrel_fur_color_cont.csv")
df_fur_col
# Out:
#   Primary Fur Color  count
# 0              Gray   2473
# 1          Cinnamon    392
# 2             Black    103

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3023 entries, 0 to 3022
# Data columns (total 36 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   X                                           3023 non-null   float64
#  1   Y                                           3023 non-null   float64
#  2   Unique Squirrel ID                          3023 non-null   object
#  3   Hectare                                     3023 non-null   object
#  4   Shift                                       3023 non-null   object
#  5   Date                                        3023 non-null   int64
#  6   Hectare Squirrel Number                     3023 non-null   int64
#  7   Age                                         2902 non-null   object
#  8   Primary Fur Color                           2968 non-null   object
#  9   Highlight Fur Color                         1937 non-null   object
# ...

# %%
df.describe()
# Out:
#                  X            Y          Date  Hectare Squirrel Number  \
# count  3023.000000  3023.000000  3.023000e+03              3023.000000
# mean    -73.967184    40.780853  1.011949e+07                 4.123718
# std       0.007726     0.010285  4.246671e+04                 3.096492
# min     -73.981159    40.764911  1.006202e+07                 1.000000
# 25%     -73.973102    40.771676  1.008202e+07                 2.000000
# 50%     -73.968594    40.778166  1.012202e+07                 3.000000
# 75%     -73.960189    40.791219  1.014202e+07                 6.000000
# max     -73.949722    40.800119  1.020202e+07                23.000000
#
#           Zip Codes  Community Districts  Borough Boundaries  \
# count      9.000000          3023.000000              3023.0
# mean   11828.222222            18.996030                 4.0
# std      995.983782             0.234339                 0.0
# min    10090.000000            11.000000                 4.0
# ...

# %%
df["Primary Fur Color"].unique()
# Out:
# array([nan, 'Gray', 'Cinnamon', 'Black'], dtype=object)

# %%
gray_squirrels_count = len(df[df["Primary Fur Color"]=="Gray"])
cinnamon_squirrels_count = len(df[df["Primary Fur Color"]=="Cinnamon"])
black_squirrels_count = len(df[df["Primary Fur Color"]=="Black"])

# %%
fur_color_dict = {
    "fur color":['Gray', 'Cinnamon', 'Black'],
    "count": [gray_squirrels_count, cinnamon_squirrels_count, black_squirrels_count]
    }
fur_color_dict
# Out:
# {'fur color': ['Gray', 'Cinnamon', 'Black'], 'count': [2473, 392, 103]}

# %%
fur_color_data = pd.DataFrame(fur_color_dict)
fur_color_data
# Out:
#   fur color  count
# 0      Gray   2473
# 1  Cinnamon    392
# 2     Black    103

# %%
fur_color_data.to_csv("fur_color_data_from_dict.csv")
